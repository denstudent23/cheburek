# %% [markdown]
# <a href="https://colab.research.google.com/github/denstudent23/cheburek/blob/main/my_project/okak_application.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Application Project
## 프로젝트 소개
이 프로젝트는 사용자를 위한 간단한 애플리케이션입니다.
## 주요 기능
- 사용자 정보 관리
- 데이터 조회 및 수정
- 편리한 UI 제공
## 사용 기술
- HTML, CSS, JavaScript
## 실행 방법
프로젝트 파일을 다운로드한 후 실행합니다.
